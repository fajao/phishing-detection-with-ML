# %%
#############
# EDA stage #
#############
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read csv
df = pd.read_csv('../Data/features.csv')

# %%
# Checking
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16800 entries, 0 to 16799
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   whois_regDate             16800 non-null  int64
#  1   whois_expDate             16800 non-null  int64
#  2   number_of.                16800 non-null  int64
#  3   url_length                16800 non-null  int64
#  4   number_of_digits          16800 non-null  int64
#  5   number_of_special_charac  16800 non-null  int64
#  6   number_of-                16800 non-null  int64
#  7   number_of//               16800 non-null  int64
#  8   number_of/                16800 non-null  int64
#  9   number_of@                16800 non-null  int64
#  10  HTTP_check                16800 non-null  int64
#  11  number_of_protocols       16800 non-null  int64
#  12  number_of_subdomains      16800 non-null  int64
#  13  IP_in_url                 16800 non-null  int64
# ...

# %%
df.head()
# Out:
#    whois_regDate  whois_expDate  number_of.  url_length  number_of_digits  \
# 0           9794           1527           2          23                 0
# 1           7084            220           2          24                 0
# 2           9964           3185           2          25                 0
# 3           9038            823           2          21                 0
# 4           8578            187           2          26                 0
#
#    number_of_special_charac  number_of-  number_of//  number_of/  number_of@  \
# 0                         0           0            1           3           0
# 1                         0           0            1           3           0
# 2                         0           0            1           3           0
# 3                         0           0            1           3           0
# 4                         0           0            1           3           0
#
# ...

# %%
df.tail()
# Out:
#        whois_regDate  whois_expDate  number_of.  url_length  number_of_digits  \
# 16795             19            346           1          23                 0
# 16796             -1             -1           3          97                 3
# 16797             -1            119           4          55                 0
# 16798             -1             -1           2          67                23
# 16799           3754            263           2          37                 0
#
#        number_of_special_charac  number_of-  number_of//  number_of/  \
# 16795                         0           0            1           4
# 16796                         1           2            1          11
# 16797                         0           0            1           3
# 16798                         0           1            1           5
# 16799                         0           0            1           3
#
#        number_of@  HTTP_check  number_of_protocols  number_of_subdomains  \
# ...

# %%
df.describe()
# Out:
#        whois_regDate  whois_expDate    number_of.    url_length  \
# count   16800.000000   16800.000000  16800.000000  16800.000000
# mean     3900.020655     437.357976      2.140833     45.770952
# std      3656.990820     685.591797      1.320636     59.209846
# min        -1.000000    -837.000000      1.000000     13.000000
# 25%        48.500000      11.000000      2.000000     24.000000
# 50%      3511.000000     214.000000      2.000000     29.000000
# 75%      6909.000000     379.000000      2.000000     44.000000
# max     14195.000000    3634.000000     33.000000   2099.000000
#
#        number_of_digits  number_of_special_charac    number_of-   number_of//  \
# count      16800.000000              16800.000000  16800.000000  16800.000000
# mean           4.983690                  0.544226      0.482262      1.004048
# std           15.543984                  3.094895      1.322706      0.096897
# ...

# %%
# Missing values
df.isnull().sum()
# Out:
# whois_regDate               0
# whois_expDate               0
# number_of.                  0
# url_length                  0
# number_of_digits            0
# number_of_special_charac    0
# number_of-                  0
# number_of//                 0
# number_of/                  0
# number_of@                  0
# HTTP_check                  0
# number_of_protocols         0
# number_of_subdomains        0
# IP_in_url                   0
# number_of_.com              0
# Port_in_URL                 0
# number_of_www               0
# short_URL                   0
# dtype: int64

# %%
# Adding label column
df['label'] = 1

# %%
df.loc[:8399, 'label'] = 0

# %%
df.label.value_counts()
# Out:
# 1    8400
# 0    8400
# Name: label, dtype: int64

# %%
# Features Distribution
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='whois_regDate', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='whois_expDate', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of.', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='url_length', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of_digits', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of_special_charac', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of-', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of//', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of/', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of@', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='HTTP_check', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of_protocols', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of_subdomains', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='IP_in_url', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of_.com', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='Port_in_URL', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='number_of_www', y='label', data=df, palette='magma', orient='h')

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.barplot(x='short_URL', y='label', data=df, palette='magma', orient='h')
# Out:
# <AxesSubplot:xlabel='short_URL', ylabel='label'>

# %%
# Scatter graphic of whois features
sns.scatterplot(x='whois_regDate', y='whois_expDate', hue='label', data=df, palette='Set1')
plt.title('Website Age vs. Expiration date (whois features)')
# Out:
# Text(0.5, 1.0, 'Website Age vs. Expiration date (whois features)')

# %%
# Multivariate Analysis
sns.pairplot(df)
plt.show()
